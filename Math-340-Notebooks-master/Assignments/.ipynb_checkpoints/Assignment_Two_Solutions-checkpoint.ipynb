# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Problem 1 ** - 4 pts each: Using the Taylor series, prove the identities.  For example, given that
#
# $$
# e^{x} = \sum_{j=0}^{\infty} \frac{x^{j}}{j!}
# $$
#
# we can show that
#
# $$
# \frac{d}{dx}e^{x} = e^{x}
# $$
#
# by seeing that
#
# \begin{align}
# \frac{d}{dx}e^{x} = & \sum_{j=0}^{\infty} \frac{d}{dx} \frac{x^{j}}{j!}\\
# = & \sum_{j=1}^{\infty} j\frac{x^{j-1}}{j!}\\
# = & \sum_{j=1}^{\infty} \frac{x^{j-1}}{(j-1)!}\\
# = & \sum_{k=0}^{\infty} \frac{x^{k}}{k!}, ~ k = j-1\\
# = & e^{x}.
# \end{align}
#
# Use the TeX provided in the problem statement to help provide the relevant details of your computations.
#
# **1a.**  Using
#     $$
#     \cos(x) = \sum_{j=0}^{\infty}\frac{(-1)^{j}x^{2j}}{(2j)!}, ~ \sin(x) = \sum_{j=0}^{\infty}\frac{(-1)^{j}x^{2j+1}}{(2j+1)!}
#     $$
#     show
#     $$
#     \frac{d}{dx}\sin(x) = \cos(x).
#     $$
#
#
#  **Solution:**
#
# \begin{align*}
#     \frac{d}{dx}\sin(x) &= \sum_{j=0}^{\infty}\frac{d}{dx}\frac{(-1)^{j}x^{2j+1}}{(2j+1)!} \\
#     &= \sum_{j=0}^{\infty}\frac{(-1)^{j}(2j+1)x^{2j}}{(2j+1)!}\\
# \end{align*}
#
# Using,
# $$
# (2j+1)! = (2j+1)(2j)!
# $$
#
# \begin{align*}
#     &= \sum_{j=0}^{\infty}\frac{(-1)^{j}(2j+1)x^{2j}}{(2j+1)!}\\
#     &= \sum_{j=0}^{\infty}\frac{(-1)^{j}(2j+1)x^{2j}}{(2j+1)(2j)!}\\
#     &=\sum_{j=0}^{\infty}\frac{(-1)^{j}x^{2j}}{(2j)!}\\
#     &= \sin(x)
# \end{align*}
#
#
#
# **1b**. Using, for $|x|<1$ and $|t|<1$ that
#     $$
#     \frac{1}{1-t} = \sum_{j=0}^{\infty}t^{j}, ~ \tan^{-1}(x) = \int_{0}^{x}\frac{dt}{1+t^{2}},
#     $$
#     show
#     $$
#     \tan^{-1}(x) = \sum_{j=0}^{\infty}(-1)^{j}\frac{x^{2j+1}}{2j+1}.
#     $$
#     Remember, when we have convergence, we have
#     $$
#     \int_{0}^{x} \sum_{j=0}^{\infty} f_{j}(t) dt = \sum_{j=0}^{\infty} \int_{0}^{x} f_{j}(t)dt.
#     $$
#
#  **Solution:**
# \begin{align*}
#     \tan^{-1}(x) &= \int_{0}^{x}\frac{dt}{1+t^{2}}dt\\
#     &= \int_{0}^{x}\frac{dt}{1-\left(-t^{2}\right)}dt\\
#     &= \int_{0}^{x} \sum_{j=0}^{\infty}\left(-t^{2}\right)^{j}dt\\
#     &= \int_{0}^{x} \sum_{j=0}^{\infty}(-1)^jt^{2j}dt\\
#     &=  \sum_{j=0}^{\infty}(-1)^{j}\frac{t^{2j+1}}{2j+1}\\
#     &= \tan^{-1}(x)
# \end{align*}

# %% [markdown]
# _ Answers to Problem 1 _

# %% [markdown]
# ** Problem 2 ** - 3 pts each: Find a relationship between the given coefficients.  By this we mean for example that if
#
# $$
# a_{j} = \frac{1}{j!}, ~ j\geq 0,
# $$
#
# then we have
#
# $$
# a_{j} = \left\{\begin{array}{rl}
# \frac{a_{j-1}}{j}, & j\geq 1, \\
# 1, & j=0.
# \end{array}\right.
# $$
#
# Note, the way to figure this out is to use the fact that if $a_{j} = 1/j!$ and $a_{j-1} = 1/(j-1)!$, then we can find the ratio of terms to be
#
# $$
# \frac{a_{j}}{a_{j-1}} = \frac{(j-1)!}{j!} = \frac{1}{j}.
# $$
#
# **2a**
# $$
# a_{j} = \frac{1}{(2j)!}, ~ j\geq 0.
# $$
# **Solution:**
# \begin{align*}
# a_{j-1} &= \frac{1}{(2(j-1))!}, ~ j\geq 1\\
# &= \frac{1}{(2j-2)!}, ~ j\geq 1\
# \end{align*}
#
# Thus,
#
# \begin{align*}
# \frac{a_{j}}{a_{j-1}} &= \frac{(2j-2)!}{(2j)!}\\
# &= \frac{(2j-2)!}{(2j)(2j-1)(2j-2)!}\\
# &= \frac{1}{4j^{2}-2j}\\
# \end{align*}
#
# Therefore,
# $$
# a_{j} = \left\{\begin{array}{rl}
# \frac{a_{j-1}}{4j^{2}-2j}, & j\geq 1, \\
# 1, & j=0.
# \end{array}\right.
# $$
#
#
# **2b.**
# $$
# a_{j} = \frac{2^{j}}{(2j-2)!}, ~ j\geq 1.
# $$
#
# **Solution:**
#
# $$
# a_{j-1} = \frac{2^{(j-1)}}{(2(j-1)-2)!}, ~ j\geq 2.
# $$
#
# \begin{align*}
# \frac{a_{j}}{a_{j-1}} &=  \frac{2^{j}}{(2j-2)!}\frac{(2j-4)!}{2^{j-1}}\\
# &=\frac{2^{j}(2j-4)!}{(2j-2)(2j-3)(2j-4)!2^{j-1}}\\
# a_{j}&=\frac{2}{4j^2-10j+6}a_{j-1}
# \end{align*}
#
# Therefore,
# $$
# a_{j} = \left\{\begin{array}{rl}
# \frac{2}{4j^2-10j+6}a_{j-1}, & j\geq 2, \\
# 2, & j=1.
# \end{array}\right.
# $$
#
# **2c.**
# $$
# a_{j}(x) = \frac{x^{j}}{j!}, ~ j\geq 0.
# $$
#
#
# **Solution:**
#
# $$
# a_{j-1}(x) = \frac{x^{(j-1)}}{(j-1)!}, ~ j\geq 1.
# $$
#
# \begin{align*}
# \frac{a_{j}}{a_{j-1}} &= \frac{x^{j}(j-1)!}{x^{j-1}j!}\\
# &= \frac{(j-1)!}{j(j-1)!x^{-1}}\\
# &= \frac{x}{j}\\
# a_{j}(x)&= \frac{x}{j}a_{j-1}(x)
# \end{align*}
#
# Therefore,
# $$
# a_{j}(x) = \left\{\begin{array}{rl}
# \frac{x}{j}a_{j-1}(x), & j\geq 1, \\
# 1, & j=0.
# \end{array}\right.
# $$
#
#
# **2d.** For $n$ a positive integer
# $$
# a_{j}(x) = \frac{1}{j!(n+j)!}\left(\frac{x}{2}\right)^{2j}, ~ j\geq 0.
# $$
#
#
# **Solution:**
#
# $$
# a_{j-1}(x) = \frac{1}{(j-1)!(n+j-1)!}\left(\frac{x}{2}\right)^{2(j-1)}, ~ j\geq 1.
# $$
#
# \begin{align*}
# \frac{a_{j}}{a_{j-1}} &=  \frac{1}{j!(n+j)!}\left(\frac{x}{2}\right)^{2j}(j-1)!(n+j-1)!\left(\frac{x}{2}\right)^{2-2j}\\
# &=\frac{(j-1)!(n+j-1)!\left(\frac{x}{2}\right)^2}{j(j-1)!(n+j)(n+j-1)!}\\
# &= \frac{\left( \frac{x}{2}\right)^{2}}{j(n+j)}\\
# a_{j}(x) &= \frac{\left( \frac{x}{2}\right)^{2}}{j(n+j)}a_{j-1}(x)
# \end{align*}
#
# Therefore,
# $$
# a_{j}(x) = \left\{\begin{array}{rl}
# \frac{\left( \frac{x}{2}\right)^{2}}{j(n+j)}a_{j-1}(x), & j\geq 1, \\
# \frac{1}{n!}, & j=0.
# \end{array}\right.
# $$

# %% [markdown]
# _ Answers to Problem 2 _:

# %% [markdown]
# ** Problem 3 **: 10 pts.  Using the given Python function for computing
#
# $$
# \cos(x) \approx T_{2n}(x) = \sum_{j=0}^{n} (-1)^{j}\frac{x^{2j}}{(2j)!}
# $$
#
# produce a plot which compares the various Taylor series approximations for $n=1, 2, 3, 4$ over the interval $[-1,3]$.  Describe over which intervals each $T_{2n}(x)$ appears to be a valid approximation and at what point you would describe the approximation as breaking down.  Yes, this is slightly subjective, but it is meant to make you think for a bit.
#
# Use the provided code below as a skeleton with which to produce your plot.  Refer to the notes for help in completing this problem.

# %%
def tn_approx(x,n):
    tot = 1.
    term = 1.
    for jj in xrange(1,n+1):
        term *= -x**2./((2*jj)*(2*jj-1))
        tot += term
    return tot

# %%
xvals = np.linspace(-1.,3.,int(2e4))

ex_vals = np.cos(xvals)

t1_app = [tn_approx(xval,1) for xval in xvals]
t2_app = [tn_approx(xval,2) for xval in xvals]
t3_app = [tn_approx(xval,3) for xval in xvals]
t4_app = [tn_approx(xval,4) for xval in xvals]

plt.plot(xvals, ex_vals, ls='-', color='C1', label="$\cos(x)$")
plt.plot(xvals, t1_app, ls='--', color='C2', label="$T_2(x)$")
plt.plot(xvals, t2_app, ls='--', color='C3', label= "$T_4(x)$")
plt.plot(xvals, t3_app, ls='--', color='C4', label= "$T_6(x)$")
plt.plot(xvals, t4_app, ls='--', color='C5', label="$T_8(x)$")

plt.legend(loc=("best"))

plt.xlim(-1,3)
plt.ylim(-1.5,1.5)

plt.xlabel('$x$')

plt.axes().set_aspect("equal")

fig=plt.gcf() # get current figure
fig.set_size_inches(9,7) # optional size

# %% [markdown]
# _Provide Explanation of Results Here_:

# %% [markdown]
# The approximation of the first Taylor series is good unti it breaks down at around the x value of 1. It fails to capture the oscillation beahvior of $\cos(x)$ and behaves as a downawrd parabola which makes sense since the highest power of the Taylor series is 2. The second Taylor approximation does a better job than $T_2$, but then breaks down at around 2, but does express some oscillatory behavior. The third Taylor series approximation does a better job at capturing the oscillating behavior that cosine presents, but then breaks down. The best approximation is $T_8$ since it is almost on top of the actual values of $\cos(x)$. The higher the Taylor series approximation the more accurate the approximation gets.
